# %%
import h5py
import numpy as np
import os
import glob
import cv2
import mahotas as mt
import csv
from matplotlib import pyplot
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import KFold, StratifiedKFold, ShuffleSplit
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.externals import joblib
from itertools import combinations
import warnings
warnings.filterwarnings('ignore')

# %%
features_name = ['glcm',
                 'lbp',
                 'hsv',
                 'correlogram',
                 'cld',
                 'ngtdm']
features_name_perm = []
results = []
scoring = "accuracy"
global_features = []

models = []
models.append(('Logistic Regression', LogisticRegression(random_state=9)))
models.append(('Linear Discriminant Analysis', LinearDiscriminantAnalysis()))
models.append(('KNeighbors', KNeighborsClassifier(n_neighbors=7)))
models.append(('Decision Tree', DecisionTreeClassifier(random_state=9)))
models.append(('RandomForest', RandomForestClassifier(n_estimators=100, random_state=9)))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(random_state=9)))
models.append(('Neural', MLPClassifier(solver='lbfgs',alpha=0.1,random_state=9,epsilon=1e-04,hidden_layer_sizes=100,activation='logistic')))

# %%
for num in range(1,len(features_name)+1):
    for name in combinations(features_name,num):
        features_name_perm.append('_'.join(map(str, name)))

# %%
images_path = "./fruit_picture"
files = [os.path.join(p) for p in os.listdir(images_path)]
files = np.array(files)

# %%
# print(global_features[1].shape, global_labels.shape)

# %%
# for f in features_name_perm:
#     print(f)
#     h5f_data = h5py.File('./output/data.h5', 'r')
#     h5f_label = h5py.File('./output/labels.h5', 'r')

#     global_features_string = h5f_data[f]
#     global_labels_string = h5f_label['labels']

#     global_features = np.array(global_features_string)
#     global_labels = np.array(global_labels_string)

#     h5f_data.close()
#     h5f_label.close()
    
#     global_features

#     for name, model in models:
#         cv_results = cross_val_score(model, global_features, global_labels, cv=10, scoring=scoring)
#         results.append({'feature':f  , 'model': name, 'accuracy_mean':cv_results.mean()})
#         msg = "%s: %f " % (name, cv_results.mean())
#         print(msg)

# %%
s = StratifiedKFold(n_splits=5,random_state=9,shuffle=True)
cnt = 0
targetName = ['banana', 'blueberry', 'cherry', 'chinese_pear', 'dragon_fruit',
              'green_apple', 'green_grape', 'guava', 'kiwi', 'longan', 'mango',
              'marian_plum', 'orange', 'passion_fruit', 'rambutan', 'red_apple',
              'rose_apple', 'salacca', 'strawberry', 'tamarind']

for f in features_name_perm:
    avg = []
    print('---------' , f , '---------')
    h5f_data = h5py.File('./output/data.h5', 'r')
    h5f_label = h5py.File('./output/labels.h5', 'r')

    global_features_string = h5f_data[f]
    global_labels_string = h5f_label['labels']

    global_features = np.array(global_features_string)
    global_labels = np.array(global_labels_string)

    h5f_data.close()
    h5f_label.close()
    
    print(np.any(np.isnan(global_features)))
    for name, model in models:
        j = 0
        accuracy = []
        msg = "%s: " % (name)
        for train_index, test_index in s.split(global_features,global_labels):
            missMatch = []
            x_train, x_test = global_features[train_index], global_features[test_index]
            y_train, y_test = global_labels[train_index], global_labels[test_index]
            name_train, name_test = files[train_index], files[test_index]
            model.fit(x_train,y_train) 
            predict = model.predict(x_test)
            accuracy.append(accuracy_score(predict,y_test))
            j = j + 1
        print(msg,np.mean(accuracy))
        avg.append(np.mean(accuracy))
    results.append({'Feature': f,
                  'Logistic Regression': avg[0],
                  'Linear Discriminant Analysis': avg[1],
                  'KNeighbors': avg[2],
                  'Decision Tree': avg[3],
                  'Random Forest': avg[4],
                  'GaussianNB': avg[5],
                  'SVM': avg[6],
                  'Neural': avg[7],
                  'Avg': np.mean(avg)})
    cnt = cnt + 1
# Out:
# --------- glcm ---------
# False
# Logistic Regression:  0.666
# Linear Discriminant Analysis:  0.76
# KNeighbors:  0.716
# Decision Tree:  0.6610000000000001
# RandomForest:  0.765
# NB:  0.677
# SVM:  0.715
# Neural:  0.821
# --------- lbp ---------
# False
# Logistic Regression:  0.787
# Linear Discriminant Analysis:  0.8049999999999999
# KNeighbors:  0.653
# Decision Tree:  0.5160000000000001
# RandomForest:  0.6910000000000001
# NB:  0.562
# SVM:  0.713
# Neural:  0.837
# --------- hsv ---------
# False
# Logistic Regression:  0.983
# Linear Discriminant Analysis:  0.982
# KNeighbors:  0.9709999999999999
# Decision Tree:  0.966
# RandomForest:  0.9950000000000001
# NB:  0.9720000000000001
# SVM:  0.975
# Neural:  0.9890000000000001
# --------- correlogram ---------
# False
# Logistic Regression:  0.309
# Linear Discriminant Analysis:  0.305
# KNeighbors:  0.27799999999999997
# Decision Tree:  0.197
# RandomForest:  0.346
# NB:  0.289
# SVM:  0.33299999999999996
# Neural:  0.313
# --------- cld ---------
# False
# Logistic Regression:  0.867
# Linear Discriminant Analysis:  0.9550000000000001
# KNeighbors:  0.7190000000000001
# Decision Tree:  0.866
# RandomForest:  0.952
# NB:  0.944
# SVM:  0.9
# Neural:  0.958
# --------- ngtdm ---------
# False
# Logistic Regression:  0.558
# Linear Discriminant Analysis:  0.57
# KNeighbors:  0.593
# Decision Tree:  0.559
# RandomForest:  0.675
# NB:  0.547
# SVM:  0.623
# Neural:  0.7330000000000001
# --------- glcm_lbp ---------
# False
# Logistic Regression:  0.891
# Linear Discriminant Analysis:  0.921
# KNeighbors:  0.7510000000000001
# Decision Tree:  0.7300000000000001
# RandomForest:  0.845
# NB:  0.7529999999999999
# SVM:  0.841
# Neural:  0.9339999999999999
# --------- glcm_hsv ---------
# False
# Logistic Regression:  0.9880000000000001
# Linear Discriminant Analysis:  0.9870000000000001
# KNeighbors:  0.9789999999999999
# Decision Tree:  0.962
# RandomForest:  0.994
# NB:  0.9780000000000001
# SVM:  0.986
# Neural:  0.991
# --------- glcm_correlogram ---------
# False
# Logistic Regression:  0.656
# Linear Discriminant Analysis:  0.7689999999999999
# KNeighbors:  0.471
# Decision Tree:  0.627
# RandomForest:  0.784
# NB:  0.6739999999999999
# SVM:  0.606
# Neural:  0.7180000000000001
# --------- glcm_cld ---------
# False
# Logistic Regression:  0.9189999999999999
# Linear Discriminant Analysis:  0.9890000000000001
# KNeighbors:  0.791
# Decision Tree:  0.907
# RandomForest:  0.975
# NB:  0.9730000000000001
# SVM:  0.95
# Neural:  0.9789999999999999
# --------- glcm_ngtdm ---------
# False
# Logistic Regression:  0.736
# Linear Discriminant Analysis:  0.78
# KNeighbors:  0.715
# Decision Tree:  0.666
# RandomForest:  0.775
# NB:  0.664
# SVM:  0.7270000000000001
# Neural:  0.8370000000000001
# --------- lbp_hsv ---------
# False
# Logistic Regression:  0.994
# Linear Discriminant Analysis:  0.9949999999999999
# KNeighbors:  0.9790000000000001
# Decision Tree:  0.96
# RandomForest:  0.9970000000000001
# NB:  0.9739999999999999
# SVM:  0.993
# Neural:  0.992
# --------- lbp_correlogram ---------
# False
# Logistic Regression:  0.782
# Linear Discriminant Analysis:  0.78
# KNeighbors:  0.538
# Decision Tree:  0.49899999999999994
# RandomForest:  0.708
# NB:  0.615
# SVM:  0.68
# Neural:  0.7929999999999999
# --------- lbp_cld ---------
# False
# Logistic Regression:  0.954
# Linear Discriminant Analysis:  0.99
# KNeighbors:  0.8029999999999999
# Decision Tree:  0.8880000000000001
# RandomForest:  0.97
# NB:  0.9550000000000001
# SVM:  0.9490000000000001
# Neural:  0.984
# --------- lbp_ngtdm ---------
# False
# Logistic Regression:  0.874
# Linear Discriminant Analysis:  0.891
# KNeighbors:  0.7310000000000001
# Decision Tree:  0.61
# RandomForest:  0.792
# NB:  0.666
# SVM:  0.808
# Neural:  0.93
# --------- hsv_correlogram ---------
# False
# Logistic Regression:  0.9799999999999999
# Linear Discriminant Analysis:  0.977
# KNeighbors:  0.9179999999999999
# Decision Tree:  0.961
# RandomForest:  0.9970000000000001
# NB:  0.966
# SVM:  0.959
# Neural:  0.9799999999999999
# --------- hsv_cld ---------
# False
# Logistic Regression:  0.986
# Linear Discriminant Analysis:  0.985
# KNeighbors:  0.9550000000000001
# Decision Tree:  0.9629999999999999
# RandomForest:  0.9949999999999999
# NB:  0.9730000000000001
# SVM:  0.9810000000000001
# Neural:  0.991
# --------- hsv_ngtdm ---------
# False
# Logistic Regression:  0.9880000000000001
# Linear Discriminant Analysis:  0.982
# KNeighbors:  0.9800000000000001
# Decision Tree:  0.967
# RandomForest:  0.9960000000000001
# NB:  0.9789999999999999
# SVM:  0.984
# Neural:  0.991
# --------- correlogram_cld ---------
# False
# Logistic Regression:  0.8419999999999999
# Linear Discriminant Analysis:  0.951
# KNeighbors:  0.558
# Decision Tree:  0.8390000000000001
# RandomForest:  0.925
# NB:  0.914
# SVM:  0.7850000000000001
# Neural:  0.9029999999999999
# --------- correlogram_ngtdm ---------
# False
# Logistic Regression:  0.578
# Linear Discriminant Analysis:  0.58
# KNeighbors:  0.377
# Decision Tree:  0.517
# RandomForest:  0.633
# NB:  0.502
# SVM:  0.514
# Neural:  0.6209999999999999
# --------- cld_ngtdm ---------
# False
# Logistic Regression:  0.9040000000000001
# Linear Discriminant Analysis:  0.969
# KNeighbors:  0.769
# Decision Tree:  0.89
# RandomForest:  0.967
# NB:  0.967
# SVM:  0.9339999999999999
# Neural:  0.9719999999999999
# --------- glcm_lbp_hsv ---------
# False
# Logistic Regression:  0.993
# Linear Discriminant Analysis:  0.9960000000000001
# KNeighbors:  0.985
# Decision Tree:  0.962
# RandomForest:  0.9940000000000001
# NB:  0.9789999999999999
# SVM:  0.993
# Neural:  0.9940000000000001
# --------- glcm_lbp_correlogram ---------
# False
# Logistic Regression:  0.884
# Linear Discriminant Analysis:  0.913
# KNeighbors:  0.625
# Decision Tree:  0.687
# RandomForest:  0.8480000000000001
# NB:  0.776
# SVM:  0.776
# Neural:  0.891
# --------- glcm_lbp_cld ---------
# False
# Logistic Regression:  0.96
# Linear Discriminant Analysis:  0.992
# KNeighbors:  0.835
# Decision Tree:  0.914
# RandomForest:  0.9810000000000001
# NB:  0.968
# SVM:  0.9549999999999998
# Neural:  0.9870000000000001
# --------- glcm_lbp_ngtdm ---------
# False
# Logistic Regression:  0.914
# Linear Discriminant Analysis:  0.9269999999999999
# KNeighbors:  0.765
# Decision Tree:  0.7020000000000001
# RandomForest:  0.833
# NB:  0.758
# SVM:  0.843
# Neural:  0.946
# --------- glcm_hsv_correlogram ---------
# False
# Logistic Regression:  0.985
# Linear Discriminant Analysis:  0.984
# KNeighbors:  0.93
# Decision Tree:  0.9640000000000001
# RandomForest:  0.994
# NB:  0.9720000000000001
# SVM:  0.967
# Neural:  0.985
# --------- glcm_hsv_cld ---------
# False
# Logistic Regression:  0.9890000000000001
# Linear Discriminant Analysis:  0.9880000000000001
# KNeighbors:  0.97
# Decision Tree:  0.968
# RandomForest:  0.9949999999999999
# NB:  0.9789999999999999
# SVM:  0.993
# Neural:  0.994
# --------- glcm_hsv_ngtdm ---------
# False
# Logistic Regression:  0.991
# Linear Discriminant Analysis:  0.9860000000000001
# KNeighbors:  0.9810000000000001
# Decision Tree:  0.9629999999999999
# RandomForest:  0.9949999999999999
# NB:  0.9780000000000001
# SVM:  0.9860000000000001
# Neural:  0.992
# --------- glcm_correlogram_cld ---------
# False
# Logistic Regression:  0.8939999999999999
# Linear Discriminant Analysis:  0.982
# KNeighbors:  0.6410000000000001
# Decision Tree:  0.906
# RandomForest:  0.966
# NB:  0.952
# SVM:  0.851
# Neural:  0.9410000000000001
# --------- glcm_correlogram_ngtdm ---------
# False
# Logistic Regression:  0.708
# Linear Discriminant Analysis:  0.8089999999999999
# KNeighbors:  0.477
# Decision Tree:  0.654
# RandomForest:  0.798
# NB:  0.698
# SVM:  0.645
# Neural:  0.7670000000000001
# --------- glcm_cld_ngtdm ---------
# False
# Logistic Regression:  0.924
# Linear Discriminant Analysis:  0.991
# KNeighbors:  0.808
# Decision Tree:  0.907
# RandomForest:  0.9690000000000001
# NB:  0.968
# SVM:  0.95
# Neural:  0.983
# --------- lbp_hsv_correlogram ---------
# False
# Logistic Regression:  0.993
# Linear Discriminant Analysis:  0.9949999999999999
# KNeighbors:  0.953
# Decision Tree:  0.96
# RandomForest:  0.9970000000000001
# NB:  0.968
# SVM:  0.9799999999999999
# Neural:  0.9960000000000001
# --------- lbp_hsv_cld ---------
# False
# Logistic Regression:  0.994
# Linear Discriminant Analysis:  0.9960000000000001
# KNeighbors:  0.9799999999999999
# Decision Tree:  0.962
# RandomForest:  0.9970000000000001
# NB:  0.976
# SVM:  0.9960000000000001
# Neural:  0.994
# --------- lbp_hsv_ngtdm ---------
# False
# Logistic Regression:  0.994
# Linear Discriminant Analysis:  0.9949999999999999
# KNeighbors:  0.9810000000000001
# Decision Tree:  0.962
# RandomForest:  0.9960000000000001
# NB:  0.9790000000000001
# SVM:  0.994
# Neural:  0.9940000000000001
# --------- lbp_correlogram_cld ---------
# False
# Logistic Regression:  0.9349999999999999
# Linear Discriminant Analysis:  0.9879999999999999
# KNeighbors:  0.679
# Decision Tree:  0.889
# RandomForest:  0.9719999999999999
# NB:  0.9369999999999999
# SVM:  0.8709999999999999
# Neural:  0.961
# --------- lbp_correlogram_ngtdm ---------
# False
# Logistic Regression:  0.86
# Linear Discriminant Analysis:  0.874
# KNeighbors:  0.584
# Decision Tree:  0.5820000000000001
# RandomForest:  0.796
# NB:  0.688
# SVM:  0.742
# Neural:  0.8540000000000001
# --------- lbp_cld_ngtdm ---------
# False
# Logistic Regression:  0.96
# Linear Discriminant Analysis:  0.992
# KNeighbors:  0.8309999999999998
# Decision Tree:  0.8949999999999999
# RandomForest:  0.975
# NB:  0.959
# SVM:  0.952
# Neural:  0.983
# --------- hsv_correlogram_cld ---------
# False
# Logistic Regression:  0.985
# Linear Discriminant Analysis:  0.9810000000000001
# KNeighbors:  0.907
# Decision Tree:  0.954
# RandomForest:  0.9950000000000001
# NB:  0.97
# SVM:  0.962
# Neural:  0.9870000000000001
# --------- hsv_correlogram_ngtdm ---------
# False
# Logistic Regression:  0.983
# Linear Discriminant Analysis:  0.9810000000000001
# KNeighbors:  0.9259999999999999
# Decision Tree:  0.9649999999999999
# RandomForest:  0.9960000000000001
# NB:  0.969
# SVM:  0.962
# Neural:  0.9880000000000001
# --------- hsv_cld_ngtdm ---------
# False
# Logistic Regression:  0.9869999999999999
# Linear Discriminant Analysis:  0.9879999999999999
# KNeighbors:  0.962
# Decision Tree:  0.9700000000000001
# RandomForest:  0.9960000000000001
# NB:  0.978
# SVM:  0.986
# Neural:  0.992
# --------- correlogram_cld_ngtdm ---------
# False
# Logistic Regression:  0.889
# Linear Discriminant Analysis:  0.9719999999999999
# KNeighbors:  0.602
# Decision Tree:  0.8879999999999999
# RandomForest:  0.961
# NB:  0.9350000000000002
# SVM:  0.837
# Neural:  0.9269999999999999
# --------- glcm_lbp_hsv_correlogram ---------
# False
# Logistic Regression:  0.9940000000000001
# Linear Discriminant Analysis:  0.9960000000000001
# KNeighbors:  0.9570000000000001
# Decision Tree:  0.9560000000000001
# RandomForest:  0.9960000000000001
# NB:  0.9729999999999999
# SVM:  0.9809999999999999
# Neural:  0.9940000000000001
# --------- glcm_lbp_hsv_cld ---------
# False
# Logistic Regression:  0.994
# Linear Discriminant Analysis:  0.9960000000000001
# KNeighbors:  0.982
# Decision Tree:  0.974
# RandomForest:  0.9970000000000001
# NB:  0.982
# SVM:  0.9970000000000001
# Neural:  0.9960000000000001
# --------- glcm_lbp_hsv_ngtdm ---------
# False
# Logistic Regression:  0.9940000000000001
# Linear Discriminant Analysis:  0.994
# KNeighbors:  0.984
# Decision Tree:  0.9649999999999999
# RandomForest:  0.9960000000000001
# NB:  0.978
# SVM:  0.9949999999999999
# Neural:  0.9940000000000001
# --------- glcm_lbp_correlogram_cld ---------
# False
# Logistic Regression:  0.95
# Linear Discriminant Analysis:  0.992
# KNeighbors:  0.7310000000000001
# Decision Tree:  0.9189999999999999
# RandomForest:  0.977
# NB:  0.952
# SVM:  0.9049999999999999
# Neural:  0.9730000000000001
# --------- glcm_lbp_correlogram_ngtdm ---------
# False
# Logistic Regression:  0.8940000000000001
# Linear Discriminant Analysis:  0.924
# KNeighbors:  0.641
# Decision Tree:  0.698
# RandomForest:  0.8469999999999999
# NB:  0.792
# SVM:  0.784
# Neural:  0.892
# --------- glcm_lbp_cld_ngtdm ---------
# False
# Logistic Regression:  0.966
# Linear Discriminant Analysis:  0.9940000000000001
# KNeighbors:  0.835
# Decision Tree:  0.9179999999999999
# RandomForest:  0.9800000000000001
# NB:  0.9649999999999999
# SVM:  0.954
# Neural:  0.9879999999999999
# --------- glcm_hsv_correlogram_cld ---------
# False
# Logistic Regression:  0.9879999999999999
# Linear Discriminant Analysis:  0.9880000000000001
# KNeighbors:  0.925
# Decision Tree:  0.9639999999999999
# RandomForest:  0.9949999999999999
# NB:  0.975
# SVM:  0.9739999999999999
# Neural:  0.9899999999999999
# --------- glcm_hsv_correlogram_ngtdm ---------
# False
# Logistic Regression:  0.986
# Linear Discriminant Analysis:  0.9860000000000001
# KNeighbors:  0.9339999999999999
# Decision Tree:  0.966
# RandomForest:  0.992
# NB:  0.9730000000000001
# SVM:  0.97
# Neural:  0.99
# --------- glcm_hsv_cld_ngtdm ---------
# False
# Logistic Regression:  0.9899999999999999
# Linear Discriminant Analysis:  0.99
# KNeighbors:  0.9729999999999999
# Decision Tree:  0.966
# RandomForest:  0.9949999999999999
# NB:  0.9789999999999999
# SVM:  0.993
# Neural:  0.993
# --------- glcm_correlogram_cld_ngtdm ---------
# False
# Logistic Regression:  0.9019999999999999
# Linear Discriminant Analysis:  0.985
# KNeighbors:  0.6529999999999999
# Decision Tree:  0.916
# RandomForest:  0.9710000000000001
# NB:  0.9480000000000001
# SVM:  0.8620000000000001
# Neural:  0.9490000000000001
# --------- lbp_hsv_correlogram_cld ---------
# False
# Logistic Regression:  0.994
# Linear Discriminant Analysis:  0.9960000000000001
# KNeighbors:  0.945
# Decision Tree:  0.959
# RandomForest:  0.9960000000000001
# NB:  0.9719999999999999
# SVM:  0.9869999999999999
# Neural:  0.9960000000000001
# --------- lbp_hsv_correlogram_ngtdm ---------
# False
# Logistic Regression:  0.9949999999999999
# Linear Discriminant Analysis:  0.9949999999999999
# KNeighbors:  0.953
# Decision Tree:  0.959
# RandomForest:  0.9960000000000001
# NB:  0.9730000000000001
# SVM:  0.982
# Neural:  0.9949999999999999
# --------- lbp_hsv_cld_ngtdm ---------
# False
# Logistic Regression:  0.994
# Linear Discriminant Analysis:  0.9969999999999999
# KNeighbors:  0.9810000000000001
# Decision Tree:  0.969
# RandomForest:  0.9960000000000001
# NB:  0.983
# SVM:  0.9949999999999999
# Neural:  0.9949999999999999
# --------- lbp_correlogram_cld_ngtdm ---------
# False
# Logistic Regression:  0.952
# Linear Discriminant Analysis:  0.9889999999999999
# KNeighbors:  0.7060000000000001
# Decision Tree:  0.881
# RandomForest:  0.9669999999999999
# NB:  0.943
# SVM:  0.891
# Neural:  0.969
# --------- hsv_correlogram_cld_ngtdm ---------
# False
# Logistic Regression:  0.9879999999999999
# Linear Discriminant Analysis:  0.9869999999999999
# KNeighbors:  0.9190000000000002
# Decision Tree:  0.967
# RandomForest:  0.9960000000000001
# NB:  0.9730000000000001
# SVM:  0.968
# Neural:  0.9890000000000001
# --------- glcm_lbp_hsv_correlogram_cld ---------
# False
# Logistic Regression:  0.9940000000000001
# Linear Discriminant Analysis:  0.9969999999999999
# KNeighbors:  0.9569999999999999
# Decision Tree:  0.9709999999999999
# RandomForest:  0.9949999999999999
# NB:  0.976
# SVM:  0.991
# Neural:  0.994
# --------- glcm_lbp_hsv_correlogram_ngtdm ---------
# False
# Logistic Regression:  0.9949999999999999
# Linear Discriminant Analysis:  0.994
# KNeighbors:  0.9549999999999998
# Decision Tree:  0.9640000000000001
# RandomForest:  0.9949999999999999
# NB:  0.9719999999999999
# SVM:  0.9789999999999999
# Neural:  0.9960000000000001
# --------- glcm_lbp_hsv_cld_ngtdm ---------
# False
# Logistic Regression:  0.994
# Linear Discriminant Analysis:  0.9969999999999999
# KNeighbors:  0.982
# Decision Tree:  0.974
# RandomForest:  0.9949999999999999
# NB:  0.9810000000000001
# SVM:  0.9970000000000001
# Neural:  0.9949999999999999
# --------- glcm_lbp_correlogram_cld_ngtdm ---------
# False
# Logistic Regression:  0.954
# Linear Discriminant Analysis:  0.991
# KNeighbors:  0.741
# Decision Tree:  0.9219999999999999
# RandomForest:  0.9730000000000001
# NB:  0.9530000000000001
# SVM:  0.909
# Neural:  0.974
# --------- glcm_hsv_correlogram_cld_ngtdm ---------
# False
# Logistic Regression:  0.9890000000000001
# Linear Discriminant Analysis:  0.99
# KNeighbors:  0.93
# Decision Tree:  0.97
# RandomForest:  0.994
# NB:  0.976
# SVM:  0.976
# Neural:  0.992
# --------- lbp_hsv_correlogram_cld_ngtdm ---------
# False
# Logistic Regression:  0.9949999999999999
# Linear Discriminant Analysis:  0.998
# KNeighbors:  0.9549999999999998
# Decision Tree:  0.96
# RandomForest:  0.9970000000000001
# NB:  0.976
# SVM:  0.9890000000000001
# Neural:  0.9960000000000001
# --------- glcm_lbp_hsv_correlogram_cld_ngtdm ---------
# False
# Logistic Regression:  0.9949999999999999
# Linear Discriminant Analysis:  0.9969999999999999
# KNeighbors:  0.96
# Decision Tree:  0.9680000000000002
# RandomForest:  0.9960000000000001
# NB:  0.976
# SVM:  0.9890000000000001
# Neural:  0.994

# %%
# s = StratifiedKFold(n_splits=5,random_state=9,shuffle=True)
# cnt = 0
# targetName = ['banana', 'blueberry', 'cherry', 'chinese_pear', 'dragon_fruit',
#               'green_apple', 'green_grape', 'guava', 'kiwi', 'longan', 'mango',
#               'marian_plum', 'orange', 'passion_fruit', 'rambutan', 'red_apple',
#               'rose_apple', 'salacca', 'strawberry', 'tamarind']

# for f in features_name_perm:
#     if f == "glcm_lbp_hsv_cld":
#         avg = []
#         print('---------' , f , '---------')
#         h5f_data = h5py.File('./output/data20-1000.h5', 'r')
#         h5f_label = h5py.File('./output/labels.h5', 'r')

#         global_features_string = h5f_data[f]
#         global_labels_string = h5f_label['labels']

#         global_features = np.array(global_features_string)
#         global_labels = np.array(global_labels_string)

#         h5f_data.close()
#         h5f_label.close()

#         print(np.any(np.isnan(global_features)))
#         for name, model in models:
#             print(name,"------------")
#             j = 0
#             accuracy = []
#             msg = "%s: " % (name)         
#             for train_index, test_index in s.split(global_features,global_labels):
#                 print(j)
#                 missMatch = []
#                 x_train, x_test = global_features[train_index], global_features[test_index]
#                 y_train, y_test = global_labels[train_index], global_labels[test_index]
#                 name_train, name_test = files[train_index], files[test_index]
#                 model.fit(x_train,y_train) 
#                 predict = model.predict(x_test)

#                 for i in range(len(predict)):
#                     if predict[i] != y_test[i]:
#                         miss = "%s : %s" % (targetName[y_test[i]] , targetName[predict[i]])
#                         missMatch.append(miss)
#                         print(name_test[i], miss)
#                 accuracy.append(accuracy_score(predict,y_test))
#                 j = j + 1            
# #             print(msg,np.mean(accuracy),accuracy)
#             avg.append(np.mean(accuracy))
#         results.append({'Feature': f,
#                       'Logistic Regression': avg[0],
#                       'Linear Discriminant Analysis': avg[1],
#                       'KNeighbors': avg[2],
#                       'Decision Tree': avg[3],
#                       'Random Forest': avg[4],
#                       'GaussianNB': avg[5],
#                       'SVM': avg[6],
#                       'Neural': avg[7],
#                       'Avg': np.mean(avg)})
#     else: pass
#     cnt = cnt + 1

# %%
keys = results[0].keys()

with open('results-5fold.csv', mode='w', newline='') as csv_file:
    fieldnames = ['Feature',
                  'Logistic Regression',
                  'Linear Discriminant Analysis',
                  'KNeighbors',
                  'Decision Tree',
                  'Random Forest',
                  'GaussianNB',
                  'SVM',
                  'Neural',
                  'Avg']
    writer = csv.DictWriter(csv_file, keys)
    writer.writeheader()
    writer.writerows(results)
